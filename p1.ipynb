# %%
'''datatypes in python...
   there are 4 datatypes
   1.int = whole number   ex:1,2,3,4,5,
   2.float = decilmal number ex:1.4,67.8....
   3.string = text/characters ex:"hello",'mansi'
   4.boolean = True/False  ex: False/True
'''
# Out:
# 'datatypes in python...\n   there are 4 datatypes\n   1.int = whole number   ex:1,2,3,4,5,\n   2.float = decilmal number ex:1.4,67.8....\n   3.string = text/characters ex:"hello",\'mansi\'\n   4.boolean = True/False  ex: False/True\n'

# %%
a=5

# %%
print(a)
# Out:
# 5

# %%
a="mansi"
a
# Out:
# 'mansi'

# %%
type(a)
# Out:
# int

# %%
a=10.6
a
# Out:
# 10.6

# %%
b=1.5

# %%
b
# Out:
# 1.5

# %%
type(b)
# Out:
# float

# %%
print(a+b)
# Out:
# 6.5

# %%
type(a+b)
# Out:
# float

# %%
c="hello"
d='world'

# %%
c,d
# Out:
# ('hello', 'world')

# %%
type(c)
# Out:
# str

# %%
print("hello" + "world")
# Out:
# helloworld

# %%
type(d)
# Out:
# str

# %%
print("hello")
type("hello")
# Out:
# hello
# str

# %%
num=False

# %%
print(num)
type(num)
# Out:
# False
# bool

# %%
'''
    advanced datatypes in python
    1.list:[] all datatypes,order,changeable, duplicates
    2.tupple:() all data types ,order,unchangeable,dublicates
    3.set:{} unorder,remove duplicates,changeable
    4.dictionary:key->value order,changeable,no key dublicates


'''

# %%
num=[1,2,3,1.6,66.8,'hello',"mansi",False]

# %%
print(num)
# Out:
# [1, 2, 3, 1.6, 66.8, 'hello', 'mansi', False]

# %%
num[0]
# Out:
# 1

# %%
num[6]
# Out:
# 'mansi'

# %%
num[0:6]
# Out:
# [1, 2, 3, 1.6, 66.8, 'hello']

# %%
num[-1]
# Out:
# False

# %%
num[-2]
# Out:
# 'mansi'

# %%
''' staring value :ending value: Gap
    mare 1 thi start kari ne end sudhi
    javu chhe but 2-2 na gap ma atale 
    starting value no index 0 ending 
    value no index+1 add karvano and 
    gap value 2
'''
num[0:8:2]
# Out:
# [1, 3, 66.8, 'mansi']

# %%
''' 
ending value j joiti hoy ena thi ek index vadhare
count karvo .....
suppose mare stat 1 thi and end mansi
joiye chhe hve 1 no index number 0 thse and mansi 
index number 6 thay chhe bt apade 6 na badle
6+1 kari ne 7 laisu'''
num[0:7]
# Out:
# [1, 2, 3, 1.6, 66.8, 'hello', 'mansi']

# %%
#tupple
num1=(1,21,56,5.6,68.9,"mansi","abc",False)

# %%
num1
# Out:
# (1, 21, 56, 5.6, 68.9, 'mansi', 'abc', False)

# %%
num1[1]
# Out:
# 21

# %%
num1[0:8:2]
# Out:
# (1, 56, 68.9, 'abc')

# %%
list=[1,2,3]

# %%
list
# Out:
# [1, 2, 3]

# %%
list.append(0)

# %%
list
# Out:
# [1, 2, 3, 0]

# %%
tup=(1,2,'hello')

# %%
tup
# Out:
# (1, 2, 'hello')

# %%
s={1,2,3,1,2,3,4,8,3,5,1,3,2,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
s.add(10)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 8, 10}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 8, 10}

# %%
s.remove(1)

# %%
s
# Out:
# {2, 3, 4, 5, 8, 10}

# %%
s.remove(10)

# %%
s
# Out:
# {2, 3, 4, 5, 8}

# %%
a="tops_techonologies"

# %%
a[0:10]
# Out:
# 'tops_techo'

# %%
a[0:10:2]
# Out:
# 'tp_eh'

# %%
a[::2]
# Out:
# 'tp_ehnlge'

# %%
a[::]
# Out:
# 'tops_techonologies'

# %%
a[::-1]
# Out:
# 'seigolonohcet_spot'

# %%
a[3::-1]
# Out:
# 'spot'

# %%
str="this is my fist python lecture "

# %%
#lenght count
len(str)
# Out:
# 31

# %%
#find value
str.find("i")
# Out:
# 2

# %%
#find value base on index number
str[8]
# Out:
# 'm'

# %%
#count how many time value apper
str.count("i")
# Out:
# 3

# %%
str.upper()
# Out:
# 'THIS IS MY FIST PYTHON LECTURE '

# %%
str.lower()
# Out:
# 'this is my fist python lecture '

# %%
#first charachater capital of every word
str.title()
# Out:
# 'This Is My Fist Python Lecture '

# %%
#capital first lecture only
str.capitalize()
# Out:
# 'This is my fist python lecture '

# %%
#slicing + uper merge two function
a[0:4].upper()
# Out:
# 'TOPS'

# %%
a[-1:-1:-1]
# Out:
# ''

# %%
a[-1:-1:10]
# Out:
# ''

# %%
a[10:-1:-1]
# Out:
# ''

# %%
a[:-1:2]
# Out:
# 'tp_ehnlge'

# %%
a[1:1:1]
# Out:
# ''

# %%
a.find("hello")
# Out:
# -1

# %%
a.find("i",5)
# Out:
# 15

# %%
a.count("s")
# Out:
# 2

# %%
s1 = "Hello"
s2 = "World"

# Using + operator
res = s1 + " " + s2
print(res)
# Out:
# Hello World

# %%
a="""hello"""
a
# Out:
# 'hello'

# %%
#the correct way to check if a variable
#  is of a specific type in Python?
var=1.4
isinstance(var, int)
# Out:
# False

# %%
#swap value
a,b=5,10
a,b=b,a
print(a)
print(b)
# Out:
# 10
# 5

# %%
a="hello word"

# %%
a
# Out:
# 'hello word'

# %%
a[3::-1]
# Out:
# 'lleh'

# %%
a[0:10:-1]
# Out:
# ''

# %%
a[0:-1:10]
# Out:
# 'h'

# %%
a[-1:10:1]
# Out:
# 'd'

# %%
a.find("o")
# Out:
# 4

# %%
a.count("l")
# Out:
# 2

# %%
a[0:11].find("l")
# Out:
# 2
